# %% [markdown]
# # Create graphs for Leakage current

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np

# %% [markdown]
# ## Import data

# %%
root_path = '../../AIMSPICE/simulation result final/' 
main_FF_20 = pd.read_csv(root_path + 'main_FF_20', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_FF_27 = pd.read_csv(root_path + 'main_FF_27', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_FF_50 = pd.read_csv(root_path + 'main_FF_50', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)

main_FS_20 = pd.read_csv(root_path + 'main_FS_20', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_FS_27 = pd.read_csv(root_path + 'main_FS_27', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_FS_50 = pd.read_csv(root_path + 'main_FS_50', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)

main_SF_20 = pd.read_csv(root_path + 'main_SF_20', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_SF_27 = pd.read_csv(root_path + 'main_SF_27', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_SF_50 = pd.read_csv(root_path + 'main_SF_50', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)

main_SS_20 = pd.read_csv(root_path + 'main_SS_20', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_SS_27 = pd.read_csv(root_path + 'main_SS_27', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_SS_50 = pd.read_csv(root_path + 'main_SS_50', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)

main_TT_20 = pd.read_csv(root_path + 'main_TT_20', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_TT_27 = pd.read_csv(root_path + 'main_TT_27', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)
main_TT_50 = pd.read_csv(root_path + 'main_TT_50', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)

Vin_Vsel_Vop = pd.read_csv(root_path + 'Vin_Vsel_Vop', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw'], skiprows=1)

main_SS_20_0_9V = pd.read_csv(root_path + '0_9_V_20_SS', sep='\t', names=['t', 'v_in', 'v_sel', 'v_rw', 'v_latch', 'v_cell'], skiprows=1)

# %% [markdown]
# ## Converter Functions

# %%
def to_micro(x, pos):
    return f"{x * 1e6:.000f}"

def to_nano(x, pos):
    return f"{x * 1e9:.000f}"

def to_pico(x, pos):
    return f"{x * 1e12:.000f}"

# %% [markdown]
# ## Plot the graph

# %% [markdown]
# ### v for stimuli

# %%
# Plot the files
plt.figure(figsize=(10, 4))
plt.title('Stimuli Voltages', fontsize=14)

plt.xticks([])
plt.yticks([])

plt.subplot(3, 1, 1)
plt.plot(Vin_Vsel_Vop['t'], Vin_Vsel_Vop['v_in'], label='v_in', linewidth=2)
plt.ylabel('$V_{in}$', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 2)
plt.plot(Vin_Vsel_Vop['t'], Vin_Vsel_Vop['v_sel'], label='v_sel', linewidth=2)
plt.ylabel('$V_{sel}$', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 3)
plt.plot(Vin_Vsel_Vop['t'], Vin_Vsel_Vop['v_rw'], label='v_rw', linewidth=2)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('$V_{rw}$', fontsize=12)
plt.xticks(np.arange(0, 9e-8, 5e-9))
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

# Customize the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Corner TT

# %%
# Plot the files
plt.figure(figsize=(10, 4))
plt.title('Latch and Cell Voltage at TT', fontsize=14)

plt.xticks([])
plt.yticks([])

plt.subplot(3, 1, 1)
plt.plot(main_TT_20['t'], main_TT_20['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_TT_20['t'], main_TT_20['v_cell'], label='$V_{cell}$', linewidth=2)
plt.legend(fontsize=12)
plt.ylabel('$V$ @ -20°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 2)
plt.plot(main_TT_27['t'], main_TT_27['v_latch'], label='v_latch_27', linewidth=2)
plt.plot(main_TT_27['t'], main_TT_27['v_cell'], label='v_cell_27', linewidth=2)
plt.ylabel('$V$ @ 27°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 3)
plt.plot(main_TT_50['t'], main_TT_50['v_latch'], label='v_latch_50', linewidth=2)
plt.plot(main_TT_50['t'], main_TT_50['v_cell'], label='v_cell_50', linewidth=2)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('$V$ @ 50°', fontsize=12)
plt.xticks(np.arange(0, 9e-8, 5e-9))
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

# Customize the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Corner FF

# %%
# Plot the files
plt.figure(figsize=(10, 4))
plt.title('Latch and Cell Voltage at FF', fontsize=14)

plt.xticks([])
plt.yticks([])

plt.subplot(3, 1, 1)
plt.plot(main_FF_20['t'], main_FF_20['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_FF_20['t'], main_FF_20['v_cell'], label='$V_{cell}$', linewidth=2)
plt.legend(fontsize=12)
plt.ylabel('$V$ @ -20°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 2)
plt.plot(main_FF_27['t'], main_FF_27['v_latch'], label='v_latch_27', linewidth=2)
plt.plot(main_FF_27['t'], main_FF_27['v_cell'], label='v_cell_27', linewidth=2)
plt.ylabel('$V$ @ 27°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 3)
plt.plot(main_FF_50['t'], main_FF_50['v_latch'], label='v_latch_50', linewidth=2)
plt.plot(main_FF_50['t'], main_FF_50['v_cell'], label='v_cell_50', linewidth=2)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('$V$ @ 50°', fontsize=12)
plt.xticks(np.arange(0, 9e-8, 5e-9))
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

# Customize the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Corner SS

# %%
# Plot the files
plt.figure(figsize=(10, 4))
plt.title('Latch and Cell Voltage at SS', fontsize=14)

plt.xticks([])
plt.yticks([])

plt.subplot(3, 1, 1)
plt.plot(main_SS_20['t'], main_SS_20['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_SS_20['t'], main_SS_20['v_cell'], label='$V_{cell}$', linewidth=2)
plt.legend(fontsize=12)
plt.ylabel('$V$ @ -20°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 2)
plt.plot(main_SS_27['t'], main_SS_27['v_latch'], label='v_latch_27', linewidth=2)
plt.plot(main_SS_27['t'], main_SS_27['v_cell'], label='v_cell_27', linewidth=2)
plt.ylabel('$V$ @ 27°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 3)
plt.plot(main_SS_50['t'], main_SS_50['v_latch'], label='v_latch_50', linewidth=2)
plt.plot(main_SS_50['t'], main_SS_50['v_cell'], label='v_cell_50', linewidth=2)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('$V$ @ 50°', fontsize=12)
plt.xticks(np.arange(0, 9e-8, 5e-9))
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

# Customize the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Corner FS

# %%
# Plot the files
plt.figure(figsize=(10, 4))
plt.title('Latch and Cell Voltage at FS', fontsize=14)

plt.xticks([])
plt.yticks([])

plt.subplot(3, 1, 1)
plt.plot(main_FS_20['t'], main_FS_20['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_FS_20['t'], main_FS_20['v_cell'], label='$V_{cell}$', linewidth=2)
plt.legend(fontsize=12)
plt.ylabel('$V$ @ -20°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 2)
plt.plot(main_FS_27['t'], main_FS_27['v_latch'], label='v_latch_27', linewidth=2)
plt.plot(main_FS_27['t'], main_FS_27['v_cell'], label='v_cell_27', linewidth=2)
plt.ylabel('$V$ @ 27°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 3)
plt.plot(main_FS_50['t'], main_FS_50['v_latch'], label='v_latch_50', linewidth=2)
plt.plot(main_FS_50['t'], main_FS_50['v_cell'], label='v_cell_50', linewidth=2)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('$V$ @ 50°', fontsize=12)
plt.xticks(np.arange(0, 9e-8, 5e-9))
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

# Customize the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Corner SF

# %%
# Plot the files
plt.figure(figsize=(10, 4))
plt.title('Latch and Cell Voltage at SF', fontsize=14)

plt.xticks([])
plt.yticks([])

plt.subplot(3, 1, 1)
plt.plot(main_SF_20['t'], main_SF_20['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_SF_20['t'], main_SF_20['v_cell'], label='$V_{cell}$', linewidth=2)
plt.legend(fontsize=12)
plt.ylabel('$V$ @ -20°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 2)
plt.plot(main_SF_27['t'], main_SF_27['v_latch'], label='v_latch_27', linewidth=2)
plt.plot(main_SF_27['t'], main_SF_27['v_cell'], label='v_cell_27', linewidth=2)
plt.ylabel('$V$ @ 27°', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

plt.subplot(3, 1, 3)
plt.plot(main_SF_50['t'], main_SF_50['v_latch'], label='v_latch_50', linewidth=2)
plt.plot(main_SF_50['t'], main_SF_50['v_cell'], label='v_cell_50', linewidth=2)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('$V$ @ 50°', fontsize=12)
plt.xticks(np.arange(0, 9e-8, 5e-9))
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(0, 8e-8)

# Customize the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Select vs cell and latch zoomed in

# %%
# Plot the files
plt.figure(figsize=(10, 4))
plt.title('Latch and Cell Voltage at 27° compared to $V_{sel}$', fontsize=14)

plt.xticks([])
plt.yticks([])

plt.subplot(3, 1, 1 )
plt.plot(main_TT_27['t'], main_TT_27['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_TT_27['t'], main_TT_27['v_cell'], label='$V_{cell}$', linewidth=2)
plt.plot(main_TT_27['t'], main_TT_27['v_sel'], label='$V_{sel}$', linewidth=2)
plt.legend(fontsize=12)
plt.ylabel('$V$ for TT', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(35e-9, 60e-9)


plt.subplot(3, 1, 2)
plt.plot(main_SS_27['t'], main_SS_27['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_SS_27['t'], main_SS_27['v_cell'], label='$V_{cell}$', linewidth=2)
plt.plot(main_SS_27['t'], main_SS_27['v_sel'], label='$V_{sel}$', linewidth=2)
plt.ylabel('$V$ for SS', fontsize=12)
plt.xticks([])
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(35e-9, 60e-9)

plt.subplot(3, 1, 3)
plt.plot(main_FF_27['t'], main_FF_27['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_FF_27['t'], main_FF_27['v_cell'], label='$V_{cell}$', linewidth=2)
plt.plot(main_FF_27['t'], main_FF_27['v_sel'], label='$V_{sel}$', linewidth=2)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('$V$ for FF', fontsize=12)
plt.xticks(np.arange(0, 9e-8, 1e-9))
plt.yticks([0, 1])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(35e-9, 60e-9)

# Customize the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## At 0.9 V NOT WORKING

# %%
# Plot the files
plt.figure(figsize=(10, 4))
plt.title('Latch and Cell Voltage at 27° and SS for $V_{in}=0.9V$', fontsize=14)

#plt.xticks([])
#plt.yticks([])

plt.plot(main_SS_20_0_9V['t'], main_SS_20_0_9V['v_latch'], label='$V_{latch}$', linewidth=2)
plt.plot(main_SS_20_0_9V['t'], main_SS_20_0_9V['v_cell'], label='$V_{cell}$', linewidth=2)
plt.plot(main_SS_20_0_9V['t'], main_SS_20_0_9V['v_sel'], label='$V_{sel}$', linewidth=2)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('$V$ for FF', fontsize=12)
plt.legend(fontsize=12)
plt.xticks(np.arange(0, 9e-8, 10e-10))
plt.yticks([0, 0.9])
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_nano))
plt.xlim(35e-9, 41e-9)

# Customize the plot
plt.tight_layout()

# Display the plot
plt.show()
